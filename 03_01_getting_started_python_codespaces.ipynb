# %% [markdown]
# # Python Fundamentals 1 — Getting started with GitHub Codespaces
#
# **Digital Foundation for Chemical Engineers**  \n
# Duration: 60 minutes
#
# ## Today’s goal
# Run Python in a browser, use Jupyter notebooks confidently, and store values in variables. Python will later let us turn chemical-engineering calculations and plant data into reproducible workflows.
#
# ### Lesson rhythm
# For each example: **watch → run it yourself → change one value → discuss**. Cells marked **Challenge** are optional extensions for students with prior Python experience.

# %% [markdown]
# ## 1. What are Python, Jupyter, and Codespaces? (10 min)
#
# - **Python** is a programming language: a precise way to give a computer instructions.
# - **Jupyter notebook** combines explanatory text (Markdown) with executable Python cells.
# - **GitHub Codespaces** provides a cloud development environment in the browser. It already includes Python for this course—no local installation is required.
#
# ### Notebook habits
# - Click a code cell and press **Shift + Enter** to run it and move on.
# - `[*]` means a cell is running; a number such as `[3]` means it has run.
# - Run cells from top to bottom. Variables remain in memory until the kernel is restarted.
# - Save often with **Ctrl/Cmd + S**.

# %%
print('Welcome to Python for Chemical Engineers!')
print('This calculation will be reproducible.')
# Out:
# Welcome to Python for Chemical Engineers!
# This calculation will be reproducible.

# %% [markdown]
# **Try it (2 min):** Change the welcome message to include your name and run the cell again.

# %% [markdown]
# ## 2. First calculations (10 min)
#
# Python can act as a calculator. `+`, `-`, `*`, `/`, and `**` mean add, subtract, multiply, divide, and power. Parentheses make the intended order clear.
#
# For a circular pipe, cross-sectional area is $A = \pi D^2/4$.

# %%
#calculate the area of circle with diameter of 
diameter_m = 0.12
area_m2 = 3.14159 * diameter_m**2 / 4
area_m2
# Out:
# 0.011309723999999998

# %% [markdown]
# **Try it (3 min):** Calculate the area for a 0.25 m diameter pipe. Add a comment beginning with `#` explaining your units.
#
# **Challenge:** Import the standard `math` library and replace `3.14159` with `math.pi`.

# %% [markdown]
# ## 3. Variables: labelled storage (15 min)
#
# A **variable** gives a meaningful name to a value. The single equals sign `=` means **assign**: put the value on the right into the name on the left. It does not mean mathematical equality.
#
# Use names that convey quantity and units: `flow_rate_m3_h` is safer than `x`.

# %%
flow_rate_m3_h = 12
operating_hours = 8
volume_m3 = flow_rate_m3_h * operating_hours

print('Processed volume:', volume_m3, 'm³')
# Out:
# Processed volume: 96 m³

# %% [markdown]
# **Think:** If you change `flow_rate_m3_h`, will `volume_m3` update by itself? Run the calculation cell again to find out.
#
# ### Good variable names
# Start with a letter or `_`; use letters, digits, and `_`; do not use spaces. Python is case-sensitive: `Temperature_C` and `temperature_c` differ.

# %%
inlet_temperature_c = 25
outlet_temperature_c = 80
temperature_rise_c = outlet_temperature_c - inlet_temperature_c
print('Temperature rise =', temperature_rise_c, '°C')

# inlet temperature c = 25  # Invalid: spaces are not allowed
# Out:
# Temperature rise = 55 °C

# %% [markdown]
# **Try it (5 min):** Create variables for mass flow rate (kg/h) and operation time (h), then calculate total mass (kg).
#
# **Challenge:** Swap two variables without typing either number a second time: `a, b = b, a`. Explain the result.

# %% [markdown]
# ## 4. Inspecting the notebook state (10 min)
#
# `print()` displays information clearly. `type()` tells us the kind of value stored. This matters because Python handles numbers and text differently.

# %%
plant_name = 'Pilot Distillation Unit'
batch_number = 17
conversion = 0.86

print(plant_name)
print(type(plant_name))
print(type(batch_number))
print(type(conversion))
# Out:
# Pilot Distillation Unit
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ## 5. Mini-practice: tank hold-up (10 min)
#
# A tank has volume 3.0 m³ and a liquid flow rate of 0.50 m³/min. Estimate residence time: $t = V/Q$.
#
# 1. Write variables with units in their names.
# 2. Calculate `residence_time_min`.
# 3. Print a readable answer.
# 4. Change the flow rate and rerun.

# %%
# Write your solution below



# Challenge: format the result to two decimal places using an f-string:
# print(f'Residence time = {residence_time_min:.2f} min')

# %% [markdown]
# ## Exit check
#
# Before leaving, you should be able to: run a cell, explain a variable, use comments, and calculate an engineering quantity with named variables.
#
# **Next hour:** data types, operators, and user input.
